# %%
#connect colab to drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
#bộ dữ liệu ISOT
#link dữ liệu: https://onlineacademiccommunity.uvic.ca/isot/2022/11/27/fake-news-detection-datasets/

df_fake = pd.read_csv("/content/gdrive/MyDrive/Colab-Notebooks/Fake.csv")
df_true = pd.read_csv("/content/gdrive/MyDrive/Colab-Notebooks/True.csv")

# %%
df_fake["class"] = 0
df_true["class"] = 1
df_fake.shape, df_true.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
df_merge = pd.concat([df_fake, df_true], axis =0 )
df_merge.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# 5  The number of cases of cops brutalizing and ki...    News
# 6  Donald Trump spent a good portion of his day a...    News
# 7  In the wake of yet another court decision that...    News
# 8  Many people have raised the alarm regarding th...    News
# 9  Just when you might have thought we d get a br...    News
#
#                 date  class
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0
# 5  December 25, 2017      0
# 6  December 23, 2017      0
# 7  December 23, 2017      0
# 8  December 22, 2017      0
# 9  December 21, 2017      0

# %%
df_merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
#loại bỏ các cột ko cần thiết, chỉ giữ lại text và class
df = df_merge.drop(["title", "subject","date"], axis = 1)

# %%
df.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
#trộn bộ dữ liệu ngẫu nhiên
df = df.sample(frac = 1)

# %%
df.head()
# Out:
#                                                     text  class
# 7316   The Washington Post reports that the Republica...      0
# 19829  DOHA (Reuters) - Qatar s defense minister has ...      1
# 202    One Nazi made the mistake of leaving his  safe...      0
# 13136  CAIRO (Reuters) - The Arab League on Tuesday c...      1
# 18018  JERUSALEM (Reuters) - The Israeli military sai...      1

# %%
df.reset_index(inplace = True)
df.drop(["index"], axis = 1, inplace = True)
df.head()
# Out:
#                                                 text  class
# 0  The Washington Post reports that the Republica...      0
# 1  DOHA (Reuters) - Qatar s defense minister has ...      1
# 2  One Nazi made the mistake of leaving his  safe...      0
# 3  CAIRO (Reuters) - The Arab League on Tuesday c...      1
# 4  JERUSALEM (Reuters) - The Israeli military sai...      1

# %%
#Loại bỏ từ dừng
def wordopt(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
type(df["text"])
# Out:
# pandas.core.series.Series

# %%
df["text"] = df["text"].apply(wordopt)

# %%
x = df["text"]
y = df["class"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
type(x_train)
# Out:
# pandas.core.series.Series

# %%
import numpy as np

train_sentences = x_train.to_numpy()
train_labels = y_train.to_numpy()

test_sentences = x_test.to_numpy()
test_labels = y_test.to_numpy()

# %%
#tạo từ vựng nhập vào nhãn train và test
int32 = np.int32
train_labels = train_labels.astype(int32)
test_labels = test_labels.astype(int32)

# %%
#Kiểm định lại tính đúng đắn của train
train_labels[0]
# Out:
# 1

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Chuyển đổi văn bản thành chuỗi số (index)

vocab_size = 30000 #kích thước
embedding_dim = 300 #số chiều
max_len = 1000 #độ dài
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>") #nhúng các token từ vựng
tokenizer.fit_on_texts(train_sentences)

# %%
num=len(tokenizer.word_index)
print(num) #in ra số lượng câu từ tập dữ liệu
# Out:
# 92650

# %%
# Lấy danh sách các từ và số nguyên tương ứng từ tokenizer
word_index_items = list(tokenizer.word_index.items())

# Kiểm tra xem có ít nhất 201 từ trong tokenizer không
print(len(word_index_items))
if len(word_index_items) >= 201:
    # Lấy từ thứ 201 trong danh sách
    word_201, index_201 = word_index_items[200]

    print(f"Từ thứ 201 trong tokenizer là: '{word_201}', có số nguyên là: {index_201}")
else:
    print("Tokenizer không có đủ 201 từ.")
# Out:
# 92650
# Từ thứ 201 trong tokenizer là: 'china', có số nguyên là: 201

# %%
tokenizer.word_index
# Out:
# {'<OOV>': 1,
#  'the': 2,
#  'to': 3,
#  'of': 4,
#  'a': 5,
#  'and': 6,
#  'in': 7,
#  's': 8,
#  'that': 9,
#  'on': 10,
#  'for': 11,
#  'is': 12,
#  'trump': 13,
#  'it': 14,
#  'he': 15,
#  'said': 16,
#  'with': 17,
#  'was': 18,
#  'as': 19,
#  'his': 20,
#  'by': 21,
#  'has': 22,
#  'be': 23,
#  'have': 24,
#  'not': 25,
#  'from': 26,
#  'this': 27,
#  'at': 28,
#  'are': 29,
#  'who': 30,
#  'an': 31,
#  'they': 32,
#  'i': 33,
#  'we': 34,
#  'but': 35,
#  'president': 36,
#  'would': 37,
#  'u': 38,
#  't': 39,
#  'about': 40,
#  'will': 41,
#  'you': 42,
#  'their': 43,
#  'had': 44,
#  'been': 45,
#  'people': 46,
#  'were': 47,
#  'or': 48,
#  'more': 49,
#  'which': 50,
#  'she': 51,
#  'one': 52,
#  'after': 53,
#  'her': 54,
#  'if': 55,
#  'all': 56,
#  'out': 57,
#  'state': 58,
#  'what': 59,
#  'when': 60,
#  'also': 61,
#  'there': 62,
#  'its': 63,
#  'up': 64,
#  'new': 65,
#  'no': 66,
#  'reuters': 67,
#  'clinton': 68,
#  'obama': 69,
#  'so': 70,
#  'over': 71,
#  'donald': 72,
#  'government': 73,
#  'house': 74,
#  'our': 75,
#  'can': 76,
#  'states': 77,
#  'republican': 78,
#  'him': 79,
#  'than': 80,
#  'year': 81,
#  'other': 82,
#  'just': 83,
#  'some': 84,
#  'could': 85,
#  'united': 86,
#  'told': 87,
#  'white': 88,
#  'into': 89,
#  'like': 90,
#  'do': 91,
#  'them': 92,
#  'against': 93,
#  'campaign': 94,
#  'because': 95,
#  'two': 96,
#  'election': 97,
#  'time': 98,
#  'last': 99,
#  'now': 100,
#  'news': 101,
#  'party': 102,
#  'any': 103,
#  'first': 104,
#  'how': 105,
#  'only': 106,
#  'washington': 107,
#  'while': 108,
#  'former': 109,
#  'country': 110,
#  'even': 111,
#  'should': 112,
#  'being': 113,
#  'us': 114,
#  'during': 115,
#  'hillary': 116,
#  'many': 117,
#  'did': 118,
#  'years': 119,
#  're': 120,
#  'before': 121,
#  'american': 122,
#  'media': 123,
#  'law': 124,
#  'most': 125,
#  'security': 126,
#  'may': 127,
#  'national': 128,
#  'made': 129,
#  'say': 130,
#  'court': 131,
#  'political': 132,
#  'those': 133,
#  'police': 134,
#  'get': 135,
#  'since': 136,
#  'percent': 137,
#  'make': 138,
#  'right': 139,
#  'where': 140,
#  'according': 141,
#  'republicans': 142,
#  'twitter': 143,
#  'these': 144,
#  'here': 145,
#  'going': 146,
#  'administration': 147,
#  'under': 148,
#  'america': 149,
#  'presidential': 150,
#  'then': 151,
#  'back': 152,
#  'very': 153,
#  'russia': 154,
#  'don': 155,
#  'democratic': 156,
#  'week': 157,
#  'bill': 158,
#  'via': 159,
#  'called': 160,
#  'senate': 161,
#  'support': 162,
#  'group': 163,
#  'north': 164,
#  'between': 165,
#  'down': 166,
#  'including': 167,
#  'way': 168,
#  'know': 169,
#  'vote': 170,
#  'think': 171,
#  'officials': 172,
#  'office': 173,
#  'well': 174,
#  'world': 175,
#  'public': 176,
#  'federal': 177,
#  'take': 178,
#  'such': 179,
#  'military': 180,
#  'department': 181,
#  'my': 182,
#  'statement': 183,
#  'million': 184,
#  'foreign': 185,
#  'day': 186,
#  'saying': 187,
#  'want': 188,
#  'tax': 189,
#  'tuesday': 190,
#  'see': 191,
#  'women': 192,
#  'both': 193,
#  'russian': 194,
#  'much': 195,
#  'still': 196,
#  'says': 197,
#  'congress': 198,
#  'another': 199,
#  'wednesday': 200,
#  'china': 201,
#  'image': 202,
#  'part': 203,
#  'your': 204,
#  'city': 205,
#  'work': 206,
#  'thursday': 207,
#  'go': 208,
#  'through': 209,
#  'friday': 210,
#  'democrats': 211,
#  'war': 212,
#  'off': 213,
#  'three': 214,
#  'policy': 215,
#  'minister': 216,
#  'asked': 217,
#  'monday': 218,
#  'own': 219,
#  'americans': 220,
#  'rights': 221,
#  'secretary': 222,
#  'committee': 223,
#  'general': 224,
#  'long': 225,
#  'york': 226,
#  'video': 227,
#  'me': 228,
#  'official': 229,
#  'black': 230,
#  'case': 231,
#  'next': 232,
#  'left': 233,
#  'need': 234,
#  'korea': 235,
#  'help': 236,
#  'deal': 237,
#  'why': 238,
#  'com': 239,
#  'whether': 240,
#  'same': 241,
#  'm': 242,
#  'show': 243,
#  'never': 244,
#  'man': 245,
#  'senator': 246,
#  'featured': 247,
#  'around': 248,
#  'order': 249,
#  'fbi': 250,
#  'leader': 251,
#  'month': 252,
#  'candidate': 253,
#  'does': 254,
#  'members': 255,
#  'good': 256,
#  'use': 257,
#  'took': 258,
#  'end': 259,
#  'every': 260,
#  'old': 261,
#  'power': 262,
#  'report': 263,
#  'come': 264,
#  'countries': 265,
#  'meeting': 266,
#  'without': 267,
#  'top': 268,
#  'investigation': 269,
#  'intelligence': 270,
#  'far': 271,
#  'used': 272,
#  'iran': 273,
#  'times': 274,
#  'put': 275,
#  'money': 276,
#  'post': 277,
#  'really': 278,
#  'justice': 279,
#  'nuclear': 280,
#  'anti': 281,
#  'reported': 282,
#  'voters': 283,
#  'decision': 284,
#  'information': 285,
#  'trade': 286,
#  'family': 287,
#  'business': 288,
#  'attack': 289,
#  'change': 290,
#  've': 291,
#  'story': 292,
#  'fact': 293,
#  'watch': 294,
#  'international': 295,
#  'leaders': 296,
#  'high': 297,
#  'plan': 298,
#  'syria': 299,
#  'south': 300,
#  'too': 301,
#  'several': 302,
#  'interview': 303,
#  'however': 304,
#  'days': 305,
#  'again': 306,
#  'director': 307,
#  'already': 308,
#  'groups': 309,
#  'chief': 310,
#  'place': 311,
#  'speech': 312,
#  'conservative': 313,
#  'health': 314,
#  'd': 315,
#  'agency': 316,
#  'immigration': 317,
#  'won': 318,
#  'today': 319,
#  'something': 320,
#  'muslim': 321,
#  'among': 322,
#  'months': 323,
#  'clear': 324,
#  'nation': 325,
#  'home': 326,
#  'pic': 327,
#  'fox': 328,
#  'program': 329,
#  'john': 330,
#  'likely': 331,
#  'must': 332,
#  'didn': 333,
#  'children': 334,
#  'border': 335,
#  'barack': 336,
#  'press': 337,
#  'call': 338,
#  'billion': 339,
#  'supporters': 340,
#  'doesn': 341,
#  'al': 342,
#  'act': 343,
#  'social': 344,
#  'believe': 345,
#  'four': 346,
#  'issue': 347,
#  'free': 348,
#  'sanders': 349,
#  'based': 350,
#  'sunday': 351,
#  'islamic': 352,
#  'recent': 353,
#  'came': 354,
#  'things': 355,
#  'seen': 356,
#  'least': 357,
#  'move': 358,
#  'might': 359,
#  'later': 360,
#  'major': 361,
#  'got': 362,
#  'control': 363,
#  'making': 364,
#  'co': 365,
#  'though': 366,
#  'number': 367,
#  'yet': 368,
#  'n': 369,
#  'found': 370,
#  'member': 371,
#  'great': 372,
#  'let': 373,
#  'working': 374,
#  'added': 375,
#  'earlier': 376,
#  'matter': 377,
#  'point': 378,
#  'reporters': 379,
#  'cnn': 380,
#  'trying': 381,
#  'defense': 382,
#  'system': 383,
#  'win': 384,
#  'economic': 385,
#  'executive': 386,
#  'known': 387,
#  'look': 388,
#  'killed': 389,
#  'spokesman': 390,
#  'past': 391,
#  'real': 392,
#  'march': 393,
#  'attacks': 394,
#  'become': 395,
#  'little': 396,
#  'until': 397,
#  'senior': 398,
#  'legal': 399,
#  'life': 400,
#  'run': 401,
#  'stop': 402,
#  'held': 403,
#  'democrat': 404,
#  'himself': 405,
#  'school': 406,
#  'violence': 407,
#  'doing': 408,
#  'led': 409,
#  'went': 410,
#  'actually': 411,
#  'january': 412,
#  'away': 413,
#  'comment': 414,
#  'thing': 415,
#  'keep': 416,
#  'forces': 417,
#  'ever': 418,
#  'governor': 419,
#  'give': 420,
#  'big': 421,
#  'eu': 422,
#  'gun': 423,
#  'set': 424,
#  'july': 425,
#  'cruz': 426,
#  'nothing': 427,
#  'human': 428,
#  'following': 429,
#  'head': 430,
#  'few': 431,
#  'majority': 432,
#  'wall': 433,
#  'care': 434,
#  'local': 435,
#  'woman': 436,
#  'person': 437,
#  'european': 438,
#  'judge': 439,
#  'issues': 440,
#  'second': 441,
#  'action': 442,
#  'union': 443,
#  'across': 444,
#  'nations': 445,
#  'job': 446,
#  'reports': 447,
#  'taking': 448,
#  'night': 449,
#  'illegal': 450,
#  'community': 451,
#  'lawmakers': 452,
#  'released': 453,
#  'force': 454,
#  'possible': 455,
#  'prime': 456,
#  'expected': 457,
#  'nominee': 458,
#  'face': 459,
#  'once': 460,
#  'attorney': 461,
#  'mexico': 462,
#  'company': 463,
#  'men': 464,
#  'wrote': 465,
#  'others': 466,
#  'source': 467,
#  'team': 468,
#  'continue': 469,
#  'enough': 470,
#  'companies': 471,
#  'sanctions': 472,
#  'given': 473,
#  'better': 474,
#  'history': 475,
#  'november': 476,
#  'pay': 477,
#  'opposition': 478,
#  'evidence': 479,
#  'legislation': 480,
#  'done': 481,
#  'open': 482,
#  'talks': 483,
#  'university': 484,
#  'five': 485,
#  'll': 486,
#  'process': 487,
#  'read': 488,
#  'question': 489,
#  'financial': 490,
#  'taken': 491,
#  'supreme': 492,
#  'course': 493,
#  'full': 494,
#  'images': 495,
#  'close': 496,
#  'despite': 497,
#  'anyone': 498,
#  'important': 499,
#  'facebook': 500,
#  'having': 501,
#  'center': 502,
#  'june': 503,
#  'special': 504,
#  'wants': 505,
#  'budget': 506,
#  'race': 507,
#  'gop': 508,
#  'hard': 509,
#  'saturday': 510,
#  'private': 511,
#  'realdonaldtrump': 512,
#  'mr': 513,
#  'response': 514,
#  'saudi': 515,
#  'instead': 516,
#  'lot': 517,
#  'using': 518,
#  'staff': 519,
#  'iraq': 520,
#  'debate': 521,
#  'further': 522,
#  'ago': 523,
#  'along': 524,
#  'ban': 525,
#  'refugees': 526,
#  'conference': 527,
#  'anything': 528,
#  'comments': 529,
#  'council': 530,
#  'https': 531,
#  'efforts': 532,
#  'plans': 533,
#  'air': 534,
#  'accused': 535,
#  'less': 536,
#  'fight': 537,
#  'putin': 538,
#  'death': 539,
#  'agreement': 540,
#  'able': 541,
#  'comey': 542,
#  'crisis': 543,
#  'region': 544,
#  'email': 545,
#  'behind': 546,
#  'syrian': 547,
#  'term': 548,
#  'best': 549,
#  'early': 550,
#  'role': 551,
#  'future': 552,
#  'within': 553,
#  'lead': 554,
#  'find': 555,
#  'ryan': 556,
#  'comes': 557,
#  'jobs': 558,
#  'line': 559,
#  'getty': 560,
#  'sure': 561,
#  'texas': 562,
#  'current': 563,
#  'letter': 564,
#  'lives': 565,
#  'israel': 566,
#  'someone': 567,
#  'civil': 568,
#  'due': 569,
#  'below': 570,
#  'name': 571,
#  'weeks': 572,
#  'running': 573,
#  'economy': 574,
#  'congressional': 575,
#  'calling': 576,
#  'coming': 577,
#  'muslims': 578,
#  'service': 579,
#  'students': 580,
#  'britain': 581,
#  'announced': 582,
#  'elections': 583,
#  'weapons': 584,
#  'late': 585,
#  'getting': 586,
#  'citizens': 587,
#  'effort': 588,
#  'visit': 589,
#  'sources': 590,
#  'live': 591,
#  'isn': 592,
#  'chairman': 593,
#  'event': 594,
#  'young': 595,
#  'street': 596,
#  'middle': 597,
#  'organization': 598,
#  'bush': 599,
#  'paul': 600,
#  'thousands': 601,
#  'speaking': 602,
#  'nearly': 603,
#  'obamacare': 604,
#  'six': 605,
#  'september': 606,
#  'talk': 607,
#  'votes': 608,
#  'coalition': 609,
#  'each': 610,
#  'daily': 611,
#  'october': 612,
#  'rule': 613,
#  'april': 614,
#  'sent': 615,
#  'army': 616,
#  'rules': 617,
#  'authorities': 618,
#  'healthcare': 619,
#  'candidates': 620,
#  'problem': 621,
#  'outside': 622,
#  'position': 623,
#  'global': 624,
#  'florida': 625,
#  'officers': 626,
#  'criminal': 627,
#  'am': 628,
#  'began': 629,
#  'capital': 630,
#  'politics': 631,
#  'ruling': 632,
#  'august': 633,
#  'whose': 634,
#  'claims': 635,
#  'front': 636,
#  'everyone': 637,
#  'allow': 638,
#  'immigrants': 639,
#  'wanted': 640,
#  'workers': 641,
#  'means': 642,
#  'december': 643,
#  'reform': 644,
#  'backed': 645,
#  'tell': 646,
#  'emails': 647,
#  'showed': 648,
#  'together': 649,
#  'east': 650,
#  'needs': 651,
#  'start': 652,
#  'hold': 653,
#  'list': 654,
#  'ties': 655,
#  'words': 656,
#  'gave': 657,
#  'representatives': 658,
#  'policies': 659,
#  'message': 660,
#  'immediately': 661,
#  'questions': 662,
#  'poll': 663,
#  'bad': 664,
#  'climate': 665,
#  'threat': 666,
#  'cut': 667,
#  'racist': 668,
#  'oil': 669,
#  'failed': 670,
#  'lost': 671,
#  'rather': 672,
#  'services': 673,
#  'stand': 674,
#  'central': 675,
#  'release': 676,
#  'germany': 677,
#  'agencies': 678,
#  'moscow': 679,
#  'pro': 680,
#  'relations': 681,
#  'funding': 682,
#  'turkey': 683,
#  'latest': 684,
#  'strong': 685,
#  'planned': 686,
#  'different': 687,
#  'almost': 688,
#  'elected': 689,
#  'leave': 690,
#  'morning': 691,
#  'access': 692,
#  'peace': 693,
#  'hope': 694,
#  'non': 695,
#  'voting': 696,
#  'recently': 697,
#  'side': 698,
#  'cannot': 699,
#  'enforcement': 700,
#  'rally': 701,
#  'reason': 702,
#  'february': 703,
#  'parliament': 704,
#  'george': 705,
#  'vice': 706,
#  'received': 707,
#  'allies': 708,
#  'shooting': 709,
#  'district': 710,
#  'involved': 711,
#  'fake': 712,
#  'large': 713,
#  'bank': 714,
#  'laws': 715,
#  'often': 716,
#  'conservatives': 717,
#  'liberal': 718,
#  'thought': 719,
#  'millions': 720,
#  'try': 721,
#  'happened': 722,
#  'tried': 723,
#  'ministry': 724,
#  'europe': 725,
#  'california': 726,
#  'spending': 727,
#  'crime': 728,
#  'chinese': 729,
#  'decided': 730,
#  'idea': 731,
#  'sexual': 732,
#  'although': 733,
#  'missile': 734,
#  'allowed': 735,
#  'level': 736,
#  'always': 737,
#  'meet': 738,
#  'protect': 739,
#  'charges': 740,
#  'small': 741,
#  'room': 742,
#  'ahead': 743,
#  'bring': 744,
#  'talking': 745,
#  'makes': 746,
#  'calls': 747,
#  'decades': 748,
#  'concerns': 749,
#  'energy': 750,
#  'situation': 751,
#  'near': 752,
#  'movement': 753,
#  'water': 754,
#  'entire': 755,
#  'denied': 756,
#  'host': 757,
#  'century': 758,
#  'tv': 759,
#  'provide': 760,
#  'officer': 761,
#  'met': 762,
#  'kind': 763,
#  'themselves': 764,
#  'j': 765,
#  'parties': 766,
#  'freedom': 767,
#  'needed': 768,
#  'key': 769,
#  'documents': 770,
#  'hate': 771,
#  'presidency': 772,
#  'son': 773,
#  'wife': 774,
#  'industry': 775,
#  'county': 776,
#  'representative': 777,
#  'everything': 778,
#  'allegations': 779,
#  'looking': 780,
#  'western': 781,
#  'terrorism': 782,
#  'agreed': 783,
#  'shot': 784,
#  'area': 785,
#  'third': 786,
#  'fire': 787,
#  'foundation': 788,
#  'return': 789,
#  'voted': 790,
#  'hours': 791,
#  'data': 792,
#  'either': 793,
#  'tweet': 794,
#  'james': 795,
#  'include': 796,
#  'fired': 797,
#  'market': 798,
#  'actions': 799,
#  'half': 800,
#  'british': 801,
#  'west': 802,
#  'terrorist': 803,
#  'interest': 804,
#  'confirmed': 805,
#  'especially': 806,
#  'polls': 807,
#  'step': 808,
#  'true': 809,
#  'nomination': 810,
#  'adding': 811,
#  'cases': 812,
#  'building': 813,
#  'elect': 814,
#  'hit': 815,
#  'potential': 816,
#  'protesters': 817,
#  'shows': 818,
#  'short': 819,
#  'commission': 820,
#  'wrong': 821,
#  'seems': 822,
#  'forward': 823,
#  'fighting': 824,
#  'myanmar': 825,
#  'clearly': 826,
#  'request': 827,
#  'insurance': 828,
#  'hearing': 829,
#  'arrested': 830,
#  'worked': 831,
#  'personal': 832,
#  'paid': 833,
#  'low': 834,
#  'serious': 835,
#  'leading': 836,
#  'continued': 837,
#  'claim': 838,
#  'primary': 839,
#  'father': 840,
#  'alleged': 841,
#  'o': 842,
#  'nov': 843,
#  'travel': 844,
#  'wasn': 845,
#  'board': 846,
#  'korean': 847,
#  'claimed': 848,
#  'address': 849,
#  'hand': 850,
#  'passed': 851,
#  'biggest': 852,
#  'record': 853,
#  'pressure': 854,
#  'spoke': 855,
#  'adviser': 856,
#  'turned': 857,
#  'soon': 858,
#  'tillerson': 859,
#  'cia': 860,
#  'bernie': 861,
#  'independence': 862,
#  'cost': 863,
#  'mean': 864,
#  'network': 865,
#  'pass': 866,
#  'truth': 867,
#  'probably': 868,
#  'families': 869,
#  'main': 870,
#  'dollars': 871,
#  'pence': 872,
#  'largest': 873,
#  'review': 874,
#  'love': 875,
#  'simply': 876,
#  'flynn': 877,
#  'brought': 878,
#  'included': 879,
#  'feel': 880,
#  'points': 881,
#  'leadership': 882,
#  'issued': 883,
#  'appeared': 884,
#  'declined': 885,
#  'michael': 886,
#  'page': 887,
#  'agenda': 888,
#  'described': 889,
#  'related': 890,
#  'posted': 891,
#  'london': 892,
#  'lawyer': 893,
#  'deputy': 894,
#  'david': 895,
#  'became': 896,
#  'result': 897,
#  'college': 898,
#  'mike': 899,
#  'view': 900,
#  'website': 901,
#  'mccain': 902,
#  'influence': 903,
#  'previously': 904,
#  'victory': 905,
#  'spent': 906,
#  'single': 907,
#  'article': 908,
#  'religious': 909,
#  'arabia': 910,
#  'remarks': 911,
#  'turn': 912,
#  'isis': 913,
#  'african': 914,
#  'started': 915,
#  'sessions': 916,
#  'constitution': 917,
#  'signed': 918,
#  'final': 919,
#  'aid': 920,
#  'mark': 921,
#  'longer': 922,
#  'armed': 923,
#  'details': 924,
#  'taxes': 925,
#  'fund': 926,
#  'class': 927,
#  'income': 928,
#  'wing': 929,
#  'friends': 930,
#  'guy': 931,
#  'toward': 932,
#  'protest': 933,
#  'sign': 934,
#  'relationship': 935,
#  'saw': 936,
#  'mayor': 937,
#  'account': 938,
#  'seven': 939,
#  'giving': 940,
#  'rubio': 941,
#  'programs': 942,
#  'raised': 943,
#  'else': 944,
#  'convention': 945,
#  'protests': 946,
#  'attempt': 947,
#  'reality': 948,
#  'child': 949,
#  'pretty': 950,
#  'independent': 951,
#  'seeking': 952,
#  'ted': 953,
#  'carolina': 954,
#  'mass': 955,
#  'debt': 956,
#  'hundreds': 957,
#  'fear': 958,
#  'conflict': 959,
#  'corruption': 960,
#  'popular': 961,
#  'food': 962,
#  'speak': 963,
#  'ambassador': 964,
#  'total': 965,
#  'heard': 966,
#  'secret': 967,
#  'created': 968,
#  'proposed': 969,
#  'militants': 970,
#  'remain': 971,
#  'firm': 972,
#  'increase': 973,
#  'similar': 974,
#  'education': 975,
#  'san': 976,
#  'forced': 977,
#  'phone': 978,
#  'crowd': 979,
#  'build': 980,
#  'violent': 981,
#  'self': 982,
#  'helped': 983,
#  'push': 984,
#  'ask': 985,
#  'lower': 986,
#  'rate': 987,
#  'repeatedly': 988,
#  'example': 989,
#  'regional': 990,
#  'areas': 991,
#  'wire': 992,
#  'town': 993,
#  'incident': 994,
#  'changes': 995,
#  'tweeted': 996,
#  'beijing': 997,
#  'criticized': 998,
#  'photo': 999,
#  'merkel': 1000,
#  ...}

# %%
#Kiểm tra xem đã xử lý được văn bản chưa
new_texts = ["elections doing run robotterror"]
new_sequences = tokenizer.texts_to_sequences(new_texts)
print(new_sequences)
# Out:
# [[583, 408, 401, 1]]

# %%
from itertools import islice
from collections import Counter

# Số lượng từ trong từ điển
num_words_in_dictionary = len(tokenizer.word_index)

# Tính tần suất xuất hiện của từng từ trong dữ liệu huấn luyện
word_frequencies = Counter(" ".join(train_sentences).split())

# In ra từ điển cùng với tần suất xuất hiện từ 20000 đến 21000
start_index, end_index = 91900, 92000
for word, index in islice(tokenizer.word_index.items(), start_index, end_index):
    frequency = word_frequencies[word] if word in word_frequencies else 0
    print(f"{word}: {index} - Tần suất xuất hiện: {frequency}")
# Out:
# unlubricated: 91901 - Tần suất xuất hiện: 1
# reeled: 91902 - Tần suất xuất hiện: 1
# waguespack: 91903 - Tần suất xuất hiện: 1
# kramatorsk: 91904 - Tần suất xuất hiện: 1
# corcovado: 91905 - Tần suất xuất hiện: 1
# fjords: 91906 - Tần suất xuất hiện: 1
# laypeople: 91907 - Tần suất xuất hiện: 1
# decontaminate: 91908 - Tần suất xuất hiện: 1
# landreth: 91909 - Tần suất xuất hiện: 1
# clayson: 91910 - Tần suất xuất hiện: 1
# awza: 91911 - Tần suất xuất hiện: 1
# bihi: 91912 - Tần suất xuất hiện: 1
# waddani: 91913 - Tần suất xuất hiện: 1
# berbera: 91914 - Tần suất xuất hiện: 1
# fileable: 91915 - Tần suất xuất hiện: 1
# jetliner: 91916 - Tần suất xuất hiện: 1
# widebody: 91917 - Tần suất xuất hiện: 1
# tenative: 91918 - Tần suất xuất hiện: 1
# portand: 91919 - Tần suất xuất hiện: 1
# seyrtnvzpl: 91920 - Tần suất xuất hiện: 1
# maydaystrike: 91921 - Tần suất xuất hiện: 1
# opdx: 91922 - Tần suất xuất hiện: 1
# quanicehayes: 91923 - Tần suất xuất hiện: 1
# pdx: 91924 - Tần suất xuất hiện: 1
# kqzuwqalok: 91925 - Tần suất xuất hiện: 1
# dax: 91926 - Tần suất xuất hiện: 1
# anondcc: 91927 - Tần suất xuất hiện: 1
# yann: 91928 - Tần suất xuất hiện: 1
# yiann: 91929 - Tần suất xuất hiện: 1
# parttime: 91930 - Tần suất xuất hiện: 1
# lingus: 91931 - Tần suất xuất hiện: 1
# colonellingus: 91932 - Tần suất xuất hiện: 1
# schick: 91933 - Tần suất xuất hiện: 1
# alumniusc: 91934 - Tần suất xuất hiện: 1
# sybeck: 91935 - Tần suất xuất hiện: 1
# veelabgm: 91936 - Tần suất xuất hiện: 1
# aristocratssoul: 91937 - Tần suất xuất hiện: 1
# slavich: 91938 - Tần suất xuất hiện: 1
# dannyslavich: 91939 - Tần suất xuất hiện: 1
# ghoulquestions: 91940 - Tần suất xuất hiện: 1
# bcfortenberry: 91941 - Tần suất xuất hiện: 1
# hsherman: 91942 - Tần suất xuất hiện: 1
# sagemonkeymafia: 91943 - Tần suất xuất hiện: 1
# exgop: 91944 - Tần suất xuất hiện: 1
# nevergoback: 91945 - Tần suất xuất hiện: 1
# polticalatheist: 91946 - Tần suất xuất hiện: 1
# miloyiannopolus: 91947 - Tần suất xuất hiện: 1
# shahriar: 91948 - Tần suất xuất hiện: 1
# rottenness: 91949 - Tần suất xuất hiện: 1
# klz: 91950 - Tần suất xuất hiện: 1
# misbehaviors: 91951 - Tần suất xuất hiện: 1
# cutis: 91952 - Tần suất xuất hiện: 1
# molo: 91953 - Tần suất xuất hiện: 1
# brickbats: 91954 - Tần suất xuất hiện: 1
# loire: 91955 - Tần suất xuất hiện: 1
# soundproofed: 91956 - Tần suất xuất hiện: 1
# presler: 91957 - Tần suất xuất hiện: 1
# fakenewshere: 91958 - Tần suất xuất hiện: 1
# prayingmedic: 91959 - Tần suất xuất hiện: 1
# unpossible: 91960 - Tần suất xuất hiện: 1
# reneecarrollphx: 91961 - Tần suất xuất hiện: 1
# xskzbwzgik: 91962 - Tần suất xuất hiện: 1
# moshed: 91963 - Tần suất xuất hiện: 1
# armband: 91964 - Tần suất xuất hiện: 1
# cauliflower: 91965 - Tần suất xuất hiện: 1
# unorganized: 91966 - Tần suất xuất hiện: 1
# catholiccharitiesusa: 91967 - Tần suất xuất hiện: 1
# ccharitiesusa: 91968 - Tần suất xuất hiện: 1
# ribeye: 91969 - Tần suất xuất hiện: 1
# redcrosshouston: 91970 - Tần suất xuất hiện: 1
# ashtonpwoods: 91971 - Tần suất xuất hiện: 1
# skittered: 91972 - Tần suất xuất hiện: 1
# inhumanely: 91973 - Tần suất xuất hiện: 1
# tatel: 91974 - Tần suất xuất hiện: 1
# laborde: 91975 - Tần suất xuất hiện: 1
# monpezat: 91976 - Tần suất xuất hiện: 1
# frederik: 91977 - Tần suất xuất hiện: 1
# gillman: 91978 - Tần suất xuất hiện: 1
# toddgillman: 91979 - Tần suất xuất hiện: 1
# bennettjohnt: 91980 - Tần suất xuất hiện: 1
# juliehdavis: 91981 - Tần suất xuất hiện: 1
# franchambers: 91982 - Tần suất xuất hiện: 1
# semtex: 91983 - Tần suất xuất hiện: 1
# avoiders: 91984 - Tần suất xuất hiện: 1
# gorscuch: 91985 - Tần suất xuất hiện: 1
# distresses: 91986 - Tần suất xuất hiện: 1
# tanes: 91987 - Tần suất xuất hiện: 1
# petsuwan: 91988 - Tần suất xuất hiện: 1
# originals: 91989 - Tần suất xuất hiện: 1
# obviates: 91990 - Tần suất xuất hiện: 1
# corrupcion: 91991 - Tần suất xuất hiện: 1
# impunidad: 91992 - Tần suất xuất hiện: 1
# meanest: 91993 - Tần suất xuất hiện: 1
# bulliest: 91994 - Tần suất xuất hiện: 1
# kershner: 91995 - Tần suất xuất hiện: 1
# nona: 91996 - Tần suất xuất hiện: 1
# canell: 91997 - Tần suất xuất hiện: 1
# solsar: 91998 - Tần suất xuất hiện: 1
# biostatistics: 91999 - Tần suất xuất hiện: 1
# loma: 92000 - Tần suất xuất hiện: 1

# %%
# Lấy dữ liệu xử lý bước trên vào tập train
train_sequences = tokenizer.texts_to_sequences(train_sentences)
padded_train_sequences = pad_sequences(train_sequences, maxlen = max_len, truncating='post', padding = 'post')

# %%
# Lấy dữ liệu xử lý bước trên vào tập test
test_sequences = tokenizer.texts_to_sequences(test_sentences)
padded_test_sequences = pad_sequences(test_sequences, maxlen = max_len, truncating='post', padding = 'post')

# %%
from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, LSTM, Dense, Dropout, GlobalMaxPooling1D, SimpleRNN, Bidirectional, concatenate

# %%
# cac hang so trong mo hinh
filters = 64
kernel_size = 3
pool_size = 2
lstm_units = 128
rnn_units = 64
dropout_rate = 0.5
num_filters = 32

# %%
# mô hình CNN
model = Sequential()

# Lớp nhúng từ
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len))

# Các lớp tích chập và pooling
model.add(Conv1D(filters=filters, kernel_size=3, activation='relu'))
model.add(GlobalMaxPooling1D())

# Lớp Fully Connected
model.add(Dense(128, activation='relu'))
model.add(Dropout(dropout_rate))

# Lớp đầu ra
model.add(Dense(1, activation='sigmoid'))

# Biên soạn mô hình
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1000, 300)         9000000
#
#  conv1d (Conv1D)             (None, 998, 64)           57664
#
#  global_max_pooling1d (Glob  (None, 64)                0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 128)               8320
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 9066113 (34.58 MB)
# Trainable params: 9066113 (34.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Huấn luyện mô hình
history = model.fit(padded_train_sequences, train_labels,batch_size = 512, epochs=5, validation_data=(padded_test_sequences, test_labels))
# Out:
# Epoch 1/5
# 62/62 [==============================] - 24s 278ms/step - loss: 0.2968 - accuracy: 0.9009 - val_loss: 0.0157 - val_accuracy: 0.9961
# Epoch 2/5
# 62/62 [==============================] - 16s 252ms/step - loss: 0.0104 - accuracy: 0.9970 - val_loss: 0.0065 - val_accuracy: 0.9982
# Epoch 3/5
# 62/62 [==============================] - 14s 230ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0050 - val_accuracy: 0.9987
# Epoch 4/5
# 62/62 [==============================] - 14s 229ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0047 - val_accuracy: 0.9988
# Epoch 5/5
# 62/62 [==============================] - 13s 204ms/step - loss: 7.1092e-04 - accuracy: 0.9999 - val_loss: 0.0049 - val_accuracy: 0.9987

# %%
model.save('/content/gdrive/MyDrive/Colab Notebooks/FakeNewDetectionCNN.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend (loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend (loc='upper right')
plt.ylabel('Cross Entropy')
plt.title( 'Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# Dự đoán trên dữ liệu mới - REAL NEWS
new_texts = ["BRUSSELS (Reuters) - NATO allies on Tuesday welcomed President Donald Trump s decision to commit more forces to Afghanistan, as part of a new U.S. strategy he said would require more troops and funding from America s partners. Having run for the White House last year on a pledge to withdraw swiftly from Afghanistan, Trump reversed course on Monday and promised a stepped-up military campaign against  Taliban insurgents, saying:  Our troops will fight to win .  U.S. officials said he had signed off on plans to send about 4,000 more U.S. troops to add to the roughly 8,400 now deployed in Afghanistan. But his speech did not define benchmarks for successfully ending the war that began with the U.S.-led invasion of Afghanistan in 2001, and which he acknowledged had required an   extraordinary sacrifice of blood and treasure .  We will ask our NATO allies and global partners to support our new strategy, with additional troops and funding increases in line with our own. We are confident they will,  Trump said. That comment signaled he would further increase pressure on U.S. partners who have already been jolted by his repeated demands to step up their contributions to NATO and his description of the alliance as  obsolete  - even though, since taking office, he has said this is no longer the case. NATO Secretary General Jens Stoltenberg said in a statement:  NATO remains fully committed to Afghanistan and I am looking forward to discussing the way ahead with (Defense) Secretary (James) Mattis and our Allies and international partners.  NATO has 12,000 troops in Afghanistan, and 15 countries have pledged more, Stoltenberg said. Britain, a leading NATO member, called the U.S. commitment  very welcome .  In my call with Secretary Mattis yesterday we agreed that despite the challenges, we have to stay the course in Afghanistan to help build up its fragile democracy and reduce the terrorist threat to the West,  Defence Secretary Michael Fallon said. Germany, which has borne the brunt of Trump s criticism over  the scale of its defense spending, also welcomed the new U.S. plan.  Our continued commitment is necessary on the path to stabilizing the country,  a government spokeswoman said. In June, European allies had already pledged more troops but had not given details on numbers, waiting for the Trump administration to outline its strategy for the region.Nearly 16 years after the U.S.-led invasion - a response to the Sept. 11 attacks which were planned by al Qaeda leader Osama bin Laden from Afghanistan - the country is still struggling with weak central government and a Taliban insurgency. Trump said he shared the frustration of the American people who were  weary of war without victory , but a hasty withdrawal would create a vacuum for groups like Islamic State and al Qaeda to fill."]
new_sequences = tokenizer.texts_to_sequences(new_texts)
new_padded_sequences = pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict(new_padded_sequences)
print("Predictions:", predictions)
# Out:
# 1/1 [==============================] - 0s 248ms/step
# Predictions: [[0.9999807]]

# %%
# Dự đoán trên dữ liệu mới - FAKE NEWS
new_texts = ["Vic Bishop Waking TimesOur reality is carefully constructed by powerful corporate, political and special interest sources in order to covertly sway public opinion. Blatant lies are often televised regarding terrorism, food, war, health, etc. They are fashioned to sway public opinion and condition viewers to accept what have become destructive societal norms.The practice of manipulating and controlling public opinion with distorted media messages has become so common that there is a whole industry formed around this. The entire role of this brainwashing industry is to figure out how to spin information to journalists, similar to the lobbying of government. It is never really clear just how much truth the journalists receive because the news industry has become complacent. The messages that it presents are shaped by corporate powers who often spend millions on advertising with the six conglomerates that own 90% of the media:General Electric (GE), News-Corp, Disney, Viacom, Time Warner, and CBS. Yet, these corporations function under many different brands, such as FOX, ABC, CNN, Comcast, Wall Street Journal, etc, giving people the perception of choice   As Tavistock s researchers showed, it was important that the victims of mass brainwashing not be aware that their environment was being controlled; there should thus be a vast number of sources for information, whose messages could be varied slightly, so as to mask the sense of external control. ~ Specialist of mass brainwashing, L. WolfeNew Brainwashing Tactic Called AstroturfWith alternative media on the rise, the propaganda machine continues to expand. Below is a video of Sharyl Attkisson, investigative reporter with CBS, during which she explains how  astroturf,  or fake grassroots movements, are used to spin information not only to influence journalists but to sway public opinion. Astroturf is a perversion of grassroots. Astroturf is when political, corporate or other special interests disguise themselves and publish blogs, start facebook and twitter accounts, publish ads, letters to the editor, or simply post comments online, to try to fool you into thinking an independent or grassroots movement is speaking. ~ Sharyl Attkisson, Investigative ReporterHow do you separate fact from fiction? Sharyl Attkisson finishes her talk with some insights on how to identify signs of propaganda and astroturfing  These methods are used to give people the impression that there is widespread support for an agenda, when, in reality, one may not exist. Astroturf tactics are also used to discredit or criticize those that disagree with certain agendas, using stereotypical names such as conspiracy theorist or quack. When in fact when someone dares to reveal the truth or questions the  official  story, it should spark a deeper curiosity and encourage further scrutiny of the information.This article (Journalist Reveals Tactics Brainwashing Industry Uses to Manipulate the Public) was originally created and published by Waking Times and is published here under a Creative Commons license with attribution to Vic Bishop and WakingTimes.com. It may be re-posted freely with proper attribution, author bio, and this copyright statement. READ MORE MSM PROPAGANDA NEWS AT: 21st Century Wire MSM Watch Files"]
new_sequences = tokenizer.texts_to_sequences(new_texts)
new_padded_sequences = pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict(new_padded_sequences)
print("Predictions:", predictions)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# Predictions: [[2.1054907e-08]]

# %%
# Du doan test
new_texts = ["Question dr ron paul outer limit radio dr paul serve twelve term u house representative threetime candidate u president devote political career defense individual liberty sound money noninterventionist foreign policy judge andrew napolitano call thomas jefferson day serve flight surgeon u air force dr paul move texas begin civilian medical practice deliver four thousand baby career obstetrician dr paul serve congress carol paul wife fifty year five child many grandchild greatgrandchildren ron paul new york post write politician buy special interest people public life thick thin rain shine stick principles added congressional colleague ron paul one ron paul never vote legislation unless propose measure expressly authorize constitution also congressman ron paul never vote raise tax ron paul never vote unbalanced budget ron paul never vote federal restriction gun ownership ron paul never vote raise congressional pay ron paul never take governmentpaid junket ron paul never vote increase power executive branch ron paul vote patriot act ron paul vote regulate internet ron paul vote iraq war ron paul participate lucrative congressional pension program ron paul chairman ron paul institute peace prosperity nonprofit educational charity host daily ron paul liberty report special thanks daniel mcadams chris rossini dylan charles chris duane mp audio link please check dr paul late book revolution ten year learn out limit radio website"]
new_sequences = tokenizer.texts_to_sequences(new_texts)
new_padded_sequences = pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict(new_padded_sequences)
print("Predictions:", predictions)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [[0.00702722]]

# %%
# Du doan test
new_texts = ["Suge knight claim tupac still alive twentyone year ago legendary u rapper tupac amaru shakur die shot street la vega september since conspiracy theory image repeatedly emerge prove rapper still alive man sit car tupac shot fire speaks make bizarre story year interview american tv station fox music mogul suge explain life imprisonment murder explain former best friend live anymore suge knight interview leave hospital pac laugh make joke ca nt understand someone state health change good bad ask believe rapper still alive suge reply tell never know pac people believe death incidentally music mogul alone opinion tupac shakur could still alive former policeman recently claim pay million euro fake tupac death official put follow word record world need know do ashamed exchange honesty money ca nt die without world knowing include popular story tupac tupac life cuba godmother political activist assata olugbala shakur suge knight kill tupac tupac back rapper kasinova tha spread music p diddy notorious big order tupac murder tupac member illuminati illuminati kill tupac become powerful tupac abducted alien fbi kill tupac related article suge knight finally admit tupac alive video elvis presley alive people convince elvis alive new photo emerge"]
new_sequences = tokenizer.texts_to_sequences(new_texts)
new_padded_sequences = pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict(new_padded_sequences)
print("Predictions:", predictions)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [[0.00026378]]

# %%
# Du doan test
new_texts = ["Senate Majority Whip John Cornyn (R-TX) thought it would be a good idea to attack Special Counsel Robert Mueller over the Russia probe. As Mueller s noose tightens, Republicans are losing their sh-t and attacking Mueller and the FBI in order to protect probably the most corrupt  president  ever.Former Attorney General Eric Holder tweeted on Friday,  Speaking on behalf of the vast majority of the American people, Republicans in Congress be forewarned: any attempt to remove Bob Mueller will not be tolerated. Cornyn retweeted Holder to say,  You don t. You don t https://t.co/7lHYkIloyz  Senator JohnCornyn (@JohnCornyn) December 16, 2017Bloomberg s Steven Dennis tweeted on Saturday that  [Cornyn] s beef is with Holder, not Mueller,  but Cornyn responded to say,  But Mueller needs to clean house of partisans. But Mueller needs to clean house of partisans https://t.co/g8SwgAKtfH  Senator JohnCornyn (@JohnCornyn) December 16, 2017The Washington Post s Greg Sargent asked Cornyn,  Will you accept the findings of the Mueller probe as legitimate, @JohnCornyn? Makes sense to me to wait to see what they are first,  Cornyn responded.Makes sense to me to wait to see what they are first https://t.co/9lCqpYujKN  Senator JohnCornyn (@JohnCornyn) December 16, 2017Republicans are trying to discredit Mueller and Twitter users took notice.If you even THINK of firing Mueller I ll make it my life s mission to make sure this is your last term, buddy.  Mrs. SMH (@MRSSMH2) December 16, 2017Carrollton, TX here Ready and willing to help get Cruz and Cornyn out  Jules012 (@JulesLorey1) December 16, 2017Garland, TX here Same! Bye Bye   TDK (@ejkmom1998) December 16, 2017Austin, TX. #IStandWithMueller. Cronyn is a fake representative. He represents his own interests and anything to profit himself  Vj (@Tex92eye) December 16, 2017I stand with Mueller!   Kenneth Shipp (@shipp_kenneth) December 16, 2017He speaks for me Its BS how you cover up for a Russia pawn If Trump not gulity why would Mueller be fired to cover up  Ellen Reeher Morris (@EllenMorris1222) December 16, 2017@EricHolder speaks for 69% of Americans according to recent polling. That s  vast majority  in my book. You were around for the Saturday Night Massacre @JohnCornyn. Firing Mueller would be X100!  Lori Winters (@LoriW66) December 16, 2017Country over party. pic.twitter.com/NXEX9rGBgu  PittieBoo (@PittieBoo) December 16, 2017He speaks for me, @JohnCornyn , and he speaks for the vast majority of American citizens who, you should remember, vote. See you in 2018.  Andrew Silver (@standsagreenoak) December 16, 2017I might just move to Texas to get those cronies tossed out of office. Blue wave is coming for the corrupt.  Ollie (@marciebp) December 16, 2017Good try, John. History will not be kind to you.Photo by Ann Heisenfelt/Getty Images"]
new_sequences = tokenizer.texts_to_sequences(new_texts)
new_padded_sequences = pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict(new_padded_sequences)
print("Predictions:", predictions)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Predictions: [[1.9653132e-07]]

# %%
#
type(padded_train_sequences[0])
# Out:
# numpy.ndarray

# %%
print()

# %%
import matplotlib.pyplot as plt
from ipywidgets import widgets, Layout, VBox
from IPython.display import display, clear_output
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Hàm kiểm tra bài báo
def kiem_tra_bai_bao(text):
    new_texts = [text]
    new_sequences = tokenizer.texts_to_sequences(new_texts)
    new_padded_sequences = pad_sequences(new_sequences, maxlen=max_len, padding='post')

    predictions = model.predict(new_padded_sequences)
    print("Predictions:", predictions)
    if predictions[0][0] > 0.5:
        confidence = predictions[0][0] * 100
        return f"Thông tin trên là đúng sự thật ({confidence:.2f}%)"
    else:
        confidence = ( predictions[0][0]) * 100
        return f"Thông tin trên là sai sự thật ({confidence:.2f}%)"

# Tạo trường nhập văn bản
text_input = widgets.Text(placeholder='Nhập văn bản bài báo', layout=Layout(width='70%', margin='0 auto 10px auto'))

# Tạo nút "Kiểm tra bài báo"
check_button = widgets.Button(description='Kiểm tra bài báo', button_style='success', layout=Layout(width='20%', margin='0 auto 10px auto'))

# Tạo nhãn hiển thị kết quả
result_label = widgets.HTML(value='', layout=Layout(margin='20px'))

# Hàm xử lý sự kiện khi nút được nhấn
def on_button_click(b):
    result = kiem_tra_bai_bao(text_input.value)
    result_label.value = result

    # Vẽ biểu đồ đơn giản
    fig, ax = plt.subplots()
    ax.plot([1, 2, 3, 4], [10, 20, 25, 30], label='Dữ liệu mẫu')
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_title('Biểu đồ đơn giản')
    ax.legend()

    # Hiển thị biểu đồ trong VBox
    with out:
        clear_output(wait=True)
        plt.show()

# Liên kết hàm xử lý sự kiện với sự kiện nhấn nút
check_button.on_click(on_button_click)

# Tạo VBox với viền ngoài hình chữ nhật và màu trắng nền
vbox = VBox([text_input, check_button, result_label], layout=Layout(width='50%', margin='0 auto', border='2px solid #000', background_color='#fff', align_items='center', justify_content='center'))

# Tạo output widget để hiển thị biểu đồ
out = widgets.Output(layout={'border': '1px solid black', 'height': '300px', 'margin': '0 auto'})

# Thêm output widget vào VBox
vbox.children += (out,)

# Đặt màu nền cho toàn bộ VBox
vbox.layout.background_color = '#fff'

# Hiển thị VBox
display(vbox)
# Out:
# VBox(children=(Text(value='', layout=Layout(margin='0 auto 10px auto', width='70%'), placeholder='Nhập văn bản…
# 1/1 [==============================] - 0s 27ms/step
# Predictions: [[0.9999807]]
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [[1.2085432e-05]]
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [[9.408211e-06]]
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [[0.9999763]]
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [[0.9980447]]
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [[0.02304686]]
# 1/1 [==============================] - 0s 25ms/step
# Predictions: [[0.99998474]]
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [[0.9993888]]
# 1/1 [==============================] - 0s 17ms/step
# Predictions: [[2.088978e-08]]
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [[1.656791e-08]]
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [[0.16666706]]
# 1/1 [==============================] - 0s 19ms/step
# Predictions: [[6.785014e-08]]
# 1/1 [==============================] - 0s 28ms/step
# Predictions: [[0.9999807]]
# 1/1 [==============================] - 0s 18ms/step
# Predictions: [[0.9999763]]
